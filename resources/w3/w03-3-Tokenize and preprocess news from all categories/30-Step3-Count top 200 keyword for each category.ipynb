# %% [markdown]
# # Calculate 200 frequent keywords for each category
#
# Count keywords from word-pos pair for each category and save them

# %%
import pandas as pd

# %%
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20240312_1  2024-03-12       政治  蒙特內哥羅媒體不畏中國施壓 拒絕撤除劉世忠專訪
#
#                                              content sentiment summary  \
# 0  駐匈牙利代表劉世忠日前接受蒙特內哥羅重要媒體「每日新聞」（Vijesti）專訪，報導刊出後遭...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('媒體', 8), ('新聞', 8), ('蒙特內哥羅', 6), ('劉世忠', 5...
#
#                                               tokens  \
# 0  ['駐', '匈牙利', '代表', '劉世忠', '日前', '接受', '蒙特內哥羅',...
#
#                                            tokens_v2  \
# 0  ['匈牙利', '代表', '劉世忠', '蒙特內哥羅', '媒體', '新聞', '中國'...
#
#                                             entities  \
# 0  [NerToken(word='匈牙利', ner='GPE', idx=(1, 4)), ...
#
#                                            token_pos  \
# 0  [('駐', 'P'), ('匈牙利', 'Nc'), ('代表', 'Na'), ('劉世...
#
#                            link  \
# 0  /news/aipl/202403120014.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/webphotos/WebCov...

# %%
df.shape
# Out:
# (9, 14)

# %%
df.groupby('category').count()
# Out:
#           item_id  date  title  content  sentiment  summary  top_key_freq  \
# category
# 政治              3     3      3        3          3        3             3
# 科技              3     3      3        3          3        3             3
# 運動              3     3      3        3          3        3             3
#
#           tokens  tokens_v2  entities  token_pos  link  photo_link
# category
# 政治             3          3         3          3     3           2
# 科技             3          3         3          3     3           1
# 運動             3          3         3          3     3           3

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20240312_1  2024-03-12       政治  蒙特內哥羅媒體不畏中國施壓 拒絕撤除劉世忠專訪
#
#                                              content sentiment summary  \
# 0  駐匈牙利代表劉世忠日前接受蒙特內哥羅重要媒體「每日新聞」（Vijesti）專訪，報導刊出後遭...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('媒體', 8), ('新聞', 8), ('蒙特內哥羅', 6), ('劉世忠', 5...
#
#                                               tokens  \
# 0  ['駐', '匈牙利', '代表', '劉世忠', '日前', '接受', '蒙特內哥羅',...
#
#                                            tokens_v2  \
# 0  ['匈牙利', '代表', '劉世忠', '蒙特內哥羅', '媒體', '新聞', '中國'...
#
#                                             entities  \
# 0  [NerToken(word='匈牙利', ner='GPE', idx=(1, 4)), ...
#
#                                            token_pos  \
# 0  [('駐', 'P'), ('匈牙利', 'Nc'), ('代表', 'Na'), ('劉世...
#
#                            link  \
# 0  /news/aipl/202403120014.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/webphotos/WebCov...

# %% [markdown]
# ## Filter category

# %%
# df_group = df[df.category == '政治']
df_group = df.query('category == "政治"')

# %%
df_group['token_pos']
# Out:
# 0    [('駐', 'P'), ('匈牙利', 'Nc'), ('代表', 'Na'), ('劉世...
# 1    [('白宮', 'Nc'), ('今天', 'Nd'), ('公布', 'VE'), ('2...
# 2    [('針對', 'P'), ('中國', 'Nc'), ('大陸籍', 'Na'), ('配...
# Name: token_pos, dtype: object

# %%
len(df_group['token_pos'])
# Out:
# 3

# %% [markdown]
# # Count top 200 word frequency for each category
#
# ## You can try it out step by step by yourself!

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
top_cate_words={} # final result
counter_all = Counter() # counter for category '全部'
for category in news_categories:
    
    # df yesterday-->This is your homework
    # df=df[(df.date >= start_date) & (df.date <= end_date)]
    
    # df category
    df_group = df[df.category == category]
    
    # concatenate all filtered words in the same category
    words_group = []
    for row in df_group.token_pos:
        
        # filter words for each news
        filtered_words =[]
        for (word, pos) in eval(row):
            if (len(word) >= 2) & (pos in allowedPOS):
                filtered_words.append(word)
                
        # concatenate filtered words  
        words_group += filtered_words

    # now we can count word frequency
    counter = Counter( words_group )
    
    # concatenate all counters 
    counter_all += counter
    topwords = counter.most_common(20)

    # store topwords
    top_cate_words[category]= topwords

# Process category '全部'
top_cate_words['全部'] = counter_all.most_common(20)

# %%
words_group
# Out:
# ['美國',
#  '職棒',
#  '大聯盟',
#  '紐約',
#  '洋基',
#  '春訓',
#  '消息',
#  '王牌',
#  '投手',
#  '柯爾',
#  '右肘',
#  '核磁共振',
#  '開幕',
#  '洋基',
#  '總教練',
#  '布恩',
#  '佛羅里達州',
#  '葡萄柚',
#  '聯盟',
#  '熱身賽',
#  '柯爾',
#  '感覺',
#  '問題',
#  '布恩',
#  '程度',
#  '傷痛',
#  '柯爾',
#  '戰績',
#  '防禦率',
#  '生涯',
#  '大聯盟',
#  '投手',
#  '榮譽賽揚獎',
#  '洋基',
#  '小傷',
#  '傷兵',
#  '名單',
#  '布恩說',
#  '球團',
#  '核磁共振',
#  '柯爾',
#  '右肘，',
#  '問題',
#  '洋基',
#  '意見',
#  '結果',
#  '柯爾',
#  '多倫多',
#  '春訓',
#  '熱身賽',
#  '特律老虎',
#  '右肘不適接受',
#  '柯爾',
#  '春訓',
#  '洋基',
#  '開幕戰',
#  '客場',
#  '休士頓',
#  '空人',
#  '柯爾',
#  '先發主投出',
#  '變數',
#  '洋基',
#  '戰績',
#  '紀錄',
#  '洋基',
#  '明星',
#  '外野手',
#  '蘇鐸',
#  '投手',
#  '陣容',
#  '大將',
#  '柯爾',
#  '團隊',
#  '戰力',
#  '打擊',
#  '輪值',
#  '柯爾',
#  '羅登',
#  '史卓曼',
#  '柯特斯',
#  '傷勢',
#  '困擾',
#  '可靠性',
#  '密特',
#  '表現',
#  '義大利',
#  '奧運',
#  '拳擊',
#  '世界區',
#  '資格賽',
#  '台灣',
#  '好手',
#  '陳念琴',
#  '陳念琴',
#  '檔案',
#  '生日',
#  '身高',
#  '體重',
#  '學歷',
#  '清華',
#  '大學',
#  '研究所',
#  '事蹟',
#  '世界',
#  '拳擊',
#  '錦標賽',
#  '女子',
#  '金牌',
#  '世界',
#  '拳擊',
#  '錦標賽',
#  '女子',
#  '量級',
#  '銅牌',
#  '女子',
#  '烏克蘭',
#  '好手',
#  '切爾諾科',
#  '奧運',
#  '門票',
#  '賽後',
#  '陳念琴',
#  '擂臺',
#  '眼眶',
#  '教練',
#  '柯文明',
#  '陳念琴',
#  '奧運',
#  '東京',
#  '奧運',
#  '奧運',
#  '大門',
#  '陳念琴',
#  '柯文明顯',
#  '中央社',
#  '記者',
#  '目標',
#  '奧運奪牌',
#  '柯文明',
#  '比賽',
#  '回合',
#  '奧運',
#  '門票',
#  '柯文明',
#  '陳念琴',
#  '資格賽',
#  '整體',
#  '表現',
#  '過程',
#  '地方',
#  '台灣',
#  '微調',
#  '大會',
#  '賽制',
#  '規定',
#  '奧運',
#  '資格賽性質',
#  '奧運',
#  '門票',
#  '賽事',
#  '關鍵',
#  '戰役',
#  '陳念琴',
#  '烏克蘭',
#  '切爾諾科連科',
#  '回合',
#  '拳路',
#  '陳念琴',
#  '裁判',
#  '陳念琴',
#  '回合',
#  '積分',
#  '回合',
#  '陳念琴',
#  '攻勢',
#  '回合',
#  '對手',
#  '裁判',
#  '青睞',
#  '積分',
#  '義大利',
#  '奧運',
#  '資格賽',
#  '台灣',
#  '黃筱雯',
#  '陳念琴',
#  '郭怡萱',
#  '杜柏緯',
#  '李承威',
#  '奧運',
#  '資格',
#  '陳念琴',
#  '門票',
#  '陳念琴',
#  '奧運',
#  '門票',
#  '台灣',
#  '林郁婷',
#  '吳詩儀',
#  '陳念琴',
#  '賴主恩',
#  '甘家葳',
#  '巴黎',
#  '奧運',
#  '拳擊',
#  '參賽權',
#  '運動',
#  '科學',
#  '體育',
#  '顯學',
#  '台師大',
#  '餐旅',
#  '研究所',
#  '教授',
#  '陳美燕',
#  '運科',
#  '計畫',
#  '運動',
#  '運科',
#  '民眾',
#  '生活',
#  '理念',
#  '台灣',
#  '國際',
#  '運動',
#  '健身展',
#  '擴能',
#  '計畫',
#  '攤位',
#  '陳美燕',
#  '媒體',
#  '運動',
#  '運動',
#  '科學',
#  '成果',
#  '影響力',
#  '社會',
#  '社會',
#  '人文',
#  '影響',
#  '運動',
#  '科學',
#  '生活',
#  '計畫',
#  '計畫',
#  '陳美燕',
#  '計畫',
#  '悠優森',
#  '運動',
#  '科學',
#  '生活',
#  '範例',
#  '悠優森',
#  '系統',
#  '民眾',
#  '路線',
#  '空氣',
#  '品質',
#  '健康幣',
#  '商家',
#  '消費',
#  '民眾',
#  '運動',
#  '賽事',
#  '應用',
#  '程式',
#  '民眾',
#  '賽事主播',
#  '民眾',
#  '主播',
#  '台灣',
#  '國際',
#  '運動',
#  '健身展',
#  '期間',
#  '桌球',
#  '奧運',
#  '國手',
#  '莊智淵',
#  '跆拳道奧運國手',
#  '陳怡安參',
#  '文創',
#  '商品',
#  '動物',
#  '議題',
#  '莊智淵',
#  '中心',
#  '餐袋',
#  '陳怡安',
#  '手工',
#  '皂盤',
#  '運動員',
#  '響力',
#  '概念']

# %%
list(top_cate_words.items())
# Out:
# [('政治',
#   [('台灣', 17),
#    ('中國', 9),
#    ('媒體', 8),
#    ('新聞', 8),
#    ('地區', 8),
#    ('蒙特內哥羅', 6),
#    ('國際', 6),
#    ('國家', 6),
#    ('人民', 6),
#    ('劉世忠', 5),
#    ('美國', 5),
#    ('台海', 4),
#    ('巴爾幹', 4),
#    ('方式', 4),
#    ('軍事', 4),
#    ('國務院', 4),
#    ('黃捷', 4),
#    ('戰爭', 3),
#    ('局勢', 3),
#    ('民主', 3)]),
#  ('科技',
#   [('馬斯克', 6),
#    ('原始碼', 6),
#    ('苯胺', 6),
#    ('火箭', 5),
#    ('公司', 4),
#    ('模型', 4),
#    ('科思', 4),
#    ('日本', 3),
#    ('船舶', 3),
#    ('人員', 3),
#    ('化學', 3),
#    ('化工', 3),
#    ('工業', 3),
#    ('大學', 3),
#    ('小型', 2),
#    ('民間', 2),
#    ('發射場', 2),
#    ('紀伊', 2),
#    ('衛星', 2),
#    ('智慧', 2)]),
#  ('運動',
#   [('陳念琴', 14),
#    ('奧運', 13),
#    ('柯爾', 9),
#    ('運動', 9),
#    ('洋基', 7),
#    ('台灣', 6),
#    ('門票', 5),
#    ('回合', 5),
#    ('計畫', 5),
#    ('民眾', 5),
#    ('拳擊', 4),
#    ('科學', 4),
#    ('春訓', 3),
#    ('投手', 3),
#    ('資格賽', 3),
#    ('女子', 3),
#    ('柯文明', 3),
#    ('陳美燕', 3),
#    ('生活', 3),
#    ('大聯盟', 2)]),
#  ('全部',
#   [('台灣', 23),
#    ('陳念琴', 14),
#    ('奧運', 13),
#    ('媒體', 9),
#    ('新聞', 9),
#    ('中國', 9),
#    ('計畫', 9),
#    ('柯爾', 9),
#    ('運動', 9),
#    ('國際', 8),
#    ('地區', 8),
#    ('美國', 7),
#    ('洋基', 7),
#    ('蒙特內哥羅', 6),
#    ('國家', 6),
#    ('人民', 6),
#    ('民眾', 6),
#    ('馬斯克', 6),
#    ('原始碼', 6),
#    ('苯胺', 6)])]

# %% [markdown]
# ## Concatenate two list

# %%
row0 = df.iloc[0].token_pos
row0
# Out:
# "[('駐', 'P'), ('匈牙利', 'Nc'), ('代表', 'Na'), ('劉世忠', 'Nb'), ('日前', 'Nd'), ('接受', 'VC'), ('蒙特內哥羅', 'Nc'), ('重要', 'VH'), ('媒體', 'Na'), ('「', 'PARENTHESISCATEGORY'), ('每日', 'Nes'), ('新聞', 'Na'), ('」', 'PARENTHESISCATEGORY'), ('（', 'PARENTHESISCATEGORY'), ('Vijesti', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('專訪', 'VC'), ('，', 'COMMACATEGORY'), ('報導', 'VE'), ('刊出', 'VE'), ('後', 'Ng'), ('遭', 'P'), ('中國', 'Nc'), ('駐', 'VCL'), ('蒙特內哥羅', 'Nc'), ('大使館', 'Nc'), ('抗議', 'VE'), ('，', 'COMMACATEGORY'), ('要求', 'VF'), ('撤除', 'VC'), ('報導', 'VE'), ('，', 'COMMACATEGORY'), ('對', 'P'), ('此', 'Nep'), ('每日', 'Nes'), ('新聞', 'Na'), ('回應', 'VC'), ('「', 'PARENTHESISCATEGORY'), ('無法', 'D'), ('移除', 'VC'), ('」', 'PARENTHESISCATEGORY'), ('，', 'COMMACATEGORY'), ('堅守', 'VJ'), ('媒體', 'Na'), ('獨立', 'VH'), ('與', 'Caa'), ('自由', 'VH'), ('。', 'PERIODCATEGORY'), ('隨', 'P'), ('烏俄', 'Nc'), ('戰爭', 'Na'), ('陷入', 'VCL'), ('僵局', 'Na'), ('，', 'COMMACATEGORY'), ('東歐', 'Nc'), ('媒體', 'Na'), ('關注', 'VJ'), ('當前', 'Nd'), ('國際', 'Nc'), ('衝突', 'Na'), ('如何', 'D'), ('影響', 'VC'), ('台海', 'Nc'), ('局勢', 'Na'), ('，', 'COMMACATEGORY'), ('駐', 'VCL'), ('匈牙利', 'Nc'), ('代表', 'Na'), ('劉世忠', 'Nb'), ('近日', 'Nd'), ('接受', 'VC'), ('兼', 'VG'), ('轄國', 'Nc'), ('多', 'Neqa'), ('家', 'Nf'), ('媒體', 'Na'), ('專訪', 'VC'), ('，', 'COMMACATEGORY'), ('分析', 'VC'), ('烏俄', 'Nc'), ('戰爭', 'Na'), ('對', 'P'), ('台海局勢', 'Nc'), ('影響', 'VC'), ('，', 'COMMACATEGORY'), ('並', 'Cbb'), ('與', 'P'), ('巴爾幹', 'Nc'), ('地區', 'Nc'), ('讀者', 'Na'), ('分享', 'VJ'), ('台灣', 'Nc'), ('民主', 'Na'), ('和', 'Caa'), ('經貿', 'Na'), ('發展', 'Na'), ('經驗', 'Na'), ('。', 'PERIODCATEGORY'), ('針對', 'P'), ('台', 'Nc'), ('海', 'Nc'), ('局勢', 'Na'), ('，', 'COMMACATEGORY'), ('劉世忠', 'Nb'), ('向', 'P'), ('蒙特內哥羅', 'Nb'), ('媒體', 'Na'), ('「', 'PARENTHESISCATEGORY'), ('每日', 'Nb'), ('新聞', 'Na'), ('」', 'PARENTHESISCATEGORY'), ('（', 'PARENTHESISCATEGORY'), ('Vijesti', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('說明', 'VE'), ('，', 'COMMACATEGORY'), ('台灣', 'Nc'), ('已', 'D'), ('是', 'SHI'), ('主權', 'Na'), ('獨立', 'VH'), ('的', 'DE'), ('民主', 'Na'), ('國家', 'Na'), ('，', 'COMMACATEGORY'), ('與', 'P'), ('中華', 'Nc'), ('人民', 'Na'), ('共和', 'Na'), ('國', 'Nc'), ('互', 'D'), ('不', 'D'), ('隸屬', 'VJ'), ('，', 'COMMACATEGORY'), ('亦', 'D'), ('無', 'VJ'), ('宣布', 'VC'), ('獨立', 'VH'), ('之', 'DE'), ('必要', 'Na'), ('，', 'COMMACATEGORY'), ('並', 'Cbb'), ('強', 'VE'), ('調', 'VC'), ('俄烏', 'Nc'), ('戰爭', 'Na'), ('的', 'DE'), ('爆發', 'VJ'), ('讓', 'VL'), ('台灣人', 'Na'), ('對', 'P'), ('威權', 'Na'), ('國家', 'Na'), ('更加', 'Dfa'), ('警覺', 'VH'), ('，', 'COMMACATEGORY'), ('捍衛', 'VC'), ('民主生活', 'Na'), ('方式', 'Na'), ('的', 'DE'), ('決心', 'Na'), ('不容', 'D'), ('挑戰', 'VC'), ('。', 'PERIODCATEGORY'), ('劉世忠', 'Nb'), ('指出', 'VE'), ('，', 'COMMACATEGORY'), ('台海', 'Nc'), ('局勢', 'Na'), ('穩定', 'VHC'), ('符合', 'VJ'), ('各', 'Nes'), ('方', 'Na'), ('利益', 'Na'), ('，', 'COMMACATEGORY'), ('包括', 'VK'), ('美', 'Nc'), ('、', 'PAUSECATEGORY'), ('日', 'Nc'), ('、', 'PAUSECATEGORY'), ('澳', 'Nc'), ('、', 'PAUSECATEGORY'), ('韓', 'Nc'), ('、', 'PAUSECATEGORY'), ('菲', 'Nc'), ('及', 'Caa'), ('多', 'Neqa'), ('個', 'Nf'), ('歐洲', 'Nc'), ('國家', 'Na'), ('在', 'P'), ('內', 'Ncd'), ('之', 'DE'), ('國際', 'Nc'), ('社會', 'Na'), ('成員', 'Na'), ('均', 'D'), ('呼籲', 'VE'), ('中國', 'Nc'), ('勿', 'D'), ('以', 'P'), ('軍事', 'Na'), ('手段', 'Na'), ('破壞', 'VC'), ('台海', 'Nc'), ('現狀', 'Na'), ('。', 'PERIODCATEGORY'), ('「', 'PARENTHESISCATEGORY'), ('每日新聞', 'Nb'), ('」', 'PARENTHESISCATEGORY'), ('也', 'D'), ('關心', 'VK'), ('北京', 'Nc'), ('經由', 'P'), ('投資', 'VC'), ('擴大', 'VC'), ('在', 'P'), ('巴爾幹', 'Nb'), ('半島', 'Na'), ('影', 'Na'), ('響力', 'Na'), ('的', 'DE'), ('問題', 'Na'), ('，', 'COMMACATEGORY'), ('對此', 'P'), ('劉世忠', 'Nb'), ('回答', 'VE'), ('，', 'COMMACATEGORY'), ('中國', 'Nc'), ('透過', 'P'), ('「', 'PARENTHESISCATEGORY'), ('一帶一路', 'Ncd'), ('」', 'PARENTHESISCATEGORY'), ('在', 'P'), ('巴爾幹', 'Nc'), ('地區', 'Nc'), ('插旗', 'VA'), ('，', 'COMMACATEGORY'), ('但', 'Cbb'), ('該', 'Nes'), ('計畫', 'VF'), ('在', 'P'), ('許多', 'Neqa'), ('國家', 'Na'), ('已', 'D'), ('造成', 'VK'), ('債務', 'Na'), ('危機', 'Na'), ('或', 'Caa'), ('貪腐問題', 'VH'), ('，', 'COMMACATEGORY'),  ...

# %%
type(row0)
# Out:
# str

# %%
row0 = eval(df.iloc[0].token_pos)
len(row0)
# Out:
# 473

# %%
row0
# Out:
# [('駐', 'P'),
#  ('匈牙利', 'Nc'),
#  ('代表', 'Na'),
#  ('劉世忠', 'Nb'),
#  ('日前', 'Nd'),
#  ('接受', 'VC'),
#  ('蒙特內哥羅', 'Nc'),
#  ('重要', 'VH'),
#  ('媒體', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Vijesti', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('專訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('報導', 'VE'),
#  ('刊出', 'VE'),
#  ('後', 'Ng'),
#  ('遭', 'P'),
#  ('中國', 'Nc'),
#  ('駐', 'VCL'),
#  ('蒙特內哥羅', 'Nc'),
#  ('大使館', 'Nc'),
#  ('抗議', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('要求', 'VF'),
#  ('撤除', 'VC'),
#  ('報導', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('對', 'P'),
#  ('此', 'Nep'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('回應', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('無法', 'D'),
#  ('移除', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('堅守', 'VJ'),
#  ('媒體', 'Na'),
#  ('獨立', 'VH'),
#  ('與', 'Caa'),
#  ('自由', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('隨', 'P'),
#  ('烏俄', 'Nc'),
#  ('戰爭', 'Na'),
#  ('陷入', 'VCL'),
#  ('僵局', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('東歐', 'Nc'),
#  ('媒體', 'Na'),
#  ('關注', 'VJ'),
#  ('當前', 'Nd'),
#  ('國際', 'Nc'),
#  ('衝突', 'Na'),
#  ('如何', 'D'),
#  ('影響', 'VC'),
#  ('台海', 'Nc'),
#  ('局勢', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('駐', 'VCL'),
#  ('匈牙利', 'Nc'),
#  ('代表', 'Na'),
#  ('劉世忠', 'Nb'),
#  ('近日', 'Nd'),
#  ('接受', 'VC'),
#  ('兼', 'VG'),
#  ('轄國', 'Nc'),
#  ('多', 'Neqa'),
#  ('家', 'Nf'),
#  ('媒體', 'Na'),
#  ('專訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('分析', 'VC'),
#  ('烏俄', 'Nc'),
#  ('戰爭', 'Na'),
#  ('對', 'P'),
#  ('台海局勢', 'Nc'),
#  ('影響', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('與', 'P'),
#  ('巴爾幹', 'Nc'),
#  ('地區', 'Nc'),
#  ('讀者', 'Na'),
#  ('分享', 'VJ'),
#  ('台灣', 'Nc'),
#  ('民主', 'Na'),
#  ('和', 'Caa'),
#  ('經貿', 'Na'),
#  ('發展', 'Na'),
#  ('經驗', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('針對', 'P'),
#  ('台', 'Nc'),
#  ('海', 'Nc'),
#  ('局勢', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('劉世忠', 'Nb'),
#  ('向', 'P'),
#  ('蒙特內哥羅', 'Nb'),
#  ('媒體', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Vijesti', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('說明', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('已', 'D'),
#  ('是', 'SHI'),
#  ('主權', 'Na'),
#  ('獨立', 'VH'),
#  ('的', 'DE'),
#  ('民主', 'Na'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('與', 'P'),
#  ('中華', 'Nc'),
#  ('人民', 'Na'),
#  ('共和', 'Na'),
#  ('國', 'Nc'),
#  ('互', 'D'),
#  ('不', 'D'),
#  ('隸屬', 'VJ'),
#  ('，', 'COMMACATEGORY'),
#  ('亦', 'D'),
#  ('無', 'VJ'),
#  ('宣布', 'VC'),
#  ('獨立', 'VH'),
#  ('之', 'DE'),
#  ('必要', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('強', 'VE'),
#  ('調', 'VC'),
#  ('俄烏', 'Nc'),
#  ('戰爭', 'Na'),
#  ('的', 'DE'),
#  ('爆發', 'VJ'),
#  ('讓', 'VL'),
#  ('台灣人', 'Na'),
#  ('對', 'P'),
#  ('威權', 'Na'),
#  ('國家', 'Na'),
#  ('更加', 'Dfa'),
#  ('警覺', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('捍衛', 'VC'),
#  ('民主生活', 'Na'),
#  ('方式', 'Na'),
#  ('的', 'DE'),
#  ('決心', 'Na'),
#  ('不容', 'D'),
#  ('挑戰', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('劉世忠', 'Nb'),
#  ('指出', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台海', 'Nc'),
#  ('局勢', 'Na'),
#  ('穩定', 'VHC'),
#  ('符合', 'VJ'),
#  ('各', 'Nes'),
#  ('方', 'Na'),
#  ('利益', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('包括', 'VK'),
#  ('美', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('日', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('澳', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('韓', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('菲', 'Nc'),
#  ('及', 'Caa'),
#  ('多', 'Neqa'),
#  ('個', 'Nf'),
#  ('歐洲', 'Nc'),
#  ('國家', 'Na'),
#  ('在', 'P'),
#  ('內', 'Ncd'),
#  ('之', 'DE'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('成員', 'Na'),
#  ('均', 'D'),
#  ('呼籲', 'VE'),
#  ('中國', 'Nc'),
#  ('勿', 'D'),
#  ('以', 'P'),
#  ('軍事', 'Na'),
#  ('手段', 'Na'),
#  ('破壞', 'VC'),
#  ('台海', 'Nc'),
#  ('現狀', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日新聞', 'Nb'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('也', 'D'),
#  ('關心', 'VK'),
#  ('北京', 'Nc'),
#  ('經由', 'P'),
#  ('投資', 'VC'),
#  ('擴大', 'VC'),
#  ('在', 'P'),
#  ('巴爾幹', 'Nb'),
#  ('半島', 'Na'),
#  ('影', 'Na'),
#  ('響力', 'Na'),
#  ('的', 'DE'),
#  ('問題', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('對此', 'P'),
#  ('劉世忠', 'Nb'),
#  ('回答', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('中國', 'Nc'),
#  ('透過', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('一帶一路', 'Ncd'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('在', 'P'),
#  ('巴爾幹', 'Nc'),
#  ('地區', 'Nc'),
#  ('插旗', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('該', 'Nes'),
#  ('計畫', 'VF'),
#  ('在', 'P'),
#  ('許多', 'Neqa'),
#  ('國家', 'Na'),
#  ('已', 'D'),
#  ('造成', 'VK'),
#  ('債務', 'Na'),
#  ('危機', 'Na'),
#  ('或', 'Caa'),
#  ('貪腐問題', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('成效', 'Na'),
#  ('不如', 'VJ'),
#  ('預期', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('反之', 'Dk'),
#  ('台灣', 'Nc'),
#  ('是', 'SHI'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('的', 'DE'),
#  ('良善', 'VH'),
#  ('力量', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('願', 'VK'),
#  ('透過', 'P'),
#  ('透明', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('公開', 'VHC'),
#  ('的', 'DE'),
#  ('方式', 'Na'),
#  ('協助', 'VC'),
#  ('巴爾幹國家', 'Nb'),
#  ('發展', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('舉例', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('在', 'P'),
#  ('蒙特內哥羅', 'Nc'),
#  ('等', 'Cab'),
#  ('巴爾幹島', 'Nc'),
#  ('國家', 'Na'),
#  ('與', 'Caa'),
#  ('歐洲', 'Nc'),
#  ('復興', 'VC'),
#  ('開發', 'VC'),
#  ('銀行', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('EBRD', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('合作', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('推動', 'VC'),
#  ('職業', 'Na'),
#  ('訓練', 'Na'),
#  ('計畫', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('造福', 'VC'),
#  ('許多', 'Neqa'),
#  ('當地', 'Nc'),
#  ('年輕', 'VH'),
#  ('學子', 'Na'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('亦', 'D'),
#  ('邀請', 'VC'),
#  ('巴爾幹', 'Nb'),
#  ('地區', 'Nc'),
#  ('產官學', 'Na'),
#  ('各', 'Na'),
#  ('界', 'Nc'),
#  ('人士', 'Na'),
#  ('赴', 'VCL'),
#  ('台', 'Nc'),
#  ('參加', 'VC'),
#  ('世界', 'Nc'),
#  ('智慧', 'Na'),
#  ('城市', 'Na'),
#  ('論壇', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('分享', 'VJ'),
#  ('台灣', 'Nc'),
#  ('成功', 'VH'),
#  ('經驗', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('專訪', 'VC'),
#  ('於', 'P'),
#  ('3月', 'Nd'),
#  ('10刊載', 'Nd'),
#  ('於', 'P'),
#  ('紙本', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('隔日', 'D'),
#  ('即', 'D'),
#  ('遭', 'P'),
#  ('中國', 'Nc'),
#  ('駐', 'VCL'),
#  ('蒙特內哥羅', 'Nc'),
#  ('大使館', 'Nc'),
#  ('抗議', 'VE'),
#  ('。', 'PERIODCATEGORY'),
#  ('面對', 'VC'),
#  ('撤除', 'VC'),
#  ('報導', 'VE'),
#  ('要求', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('僅', 'Da'),
#  ('向', 'P'),
#  ('對方', 'Nh'),
#  ('回應', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('無法', 'D'),
#  ('移除', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('專訪', 'VC'),
#  ('於', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('蒙語', 'Nb'),
#  ('與', 'Caa'),
#  ('英文', 'Na'),
#  ('入', 'Nc'),
#  ('口', 'Na'),
#  ('網站', 'Nc'),
#  ('目前', 'Nd'),
#  ('共計', 'VJ'),
#  ('有', 'V_2'),
#  ('近', 'Da'),
#  ('6萬', 'Neu'),
#  ('瀏覽', 'VC'),
#  ('人次', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('隸屬', 'VJ'),
#  ('蒙特內哥羅', 'Nb'),
#  ('最', 'Dfa'),
#  ('大', 'VH'),
#  ('媒體', 'Na'),
#  ('集團', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('為', 'P'),
#  ('中間', 'Ncd'),
#  ('偏左', 'VJ'),
#  ('及', 'Caa'),
#  ('親', 'Na'),
#  ('歐派', 'Nc'),
#  ('媒體', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2018年', 'Neu'),
#  ('該', 'Nes'),
#  ('報', 'Na'),
#  ('調查', 'VE'),
#  ('記者', 'Na'),
#  ('拉基奇', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Olivera', 'FW'),
#  (' Lakić', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('因', 'Cbb'),
#  ('長期', 'Na'),
#  ('追蹤', 'VC'),
#  ('當地', 'Nc'),
#  ('政商', 'Na'),
#  ('勾結', 'VC'),
#  ('與', 'Caa'),
#  ('腐敗', 'VH'),
#  ('的', 'DE'),
#  ('新聞', 'Na'),
#  ('遭', 'P'),
#  ('槍擊', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('引起', 'VC'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('關注', 'VJ'),
#  ('。', 'PERIODCATEGORY'),
#  ('隨著', 'P'),
#  ('去年', 'Nd'),
#  ('親', 'Nb'),
#  ('歐派', 'Nb'),
#  ('總統', 'Na'),
#  ('米', 'Nb'),
#  ('拉托維奇', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Jakov Milatović', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('上任', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('蒙', 'Nb'),
#  ('特內哥羅正', 'Nc'),
#  ('加速', 'D'),
#  ('推動', 'VC'),
#  ('入歐', 'VCL'),
#  ('，', 'COMMACATEGORY'),
#  ('在', 'P'),
#  ('成為', 'VG'),
#  ('歐盟', 'Nb'),
#  ('成員國', 'Na'),
#  ('之前', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('蒙國', 'Nc'),
#  ('必須', 'D'),
#  ('更', 'Dfa'),
#  ('強化', 'VHC'),
#  ('新聞', 'Na'),
#  ('自由', 'Na'),
#  ('與', 'Caa'),
#  ('記者', 'Na'),
#  ('安全', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('以', 'Cbb'),
#  ('符合', 'VJ'),
#  ('歐盟對', 'Nb'),
#  ('成員國', 'Na'),
#  ('媒體', 'Na'),
#  ('安全', 'VH'),
#  ('與', 'Caa'),
#  ('自由', 'VH'),
#  ('的', 'DE'),
#  ('嚴格', 'VH'),
#  ('標準', 'Na'),
#  ('。', 'PERIODCATEGORY')]

# %%
row1 = eval(df.iloc[1].token_pos)

# %%
row1
# Out:
# [('白宮', 'Nc'),
#  ('今天', 'Nd'),
#  ('公布', 'VE'),
#  ('2025', 'Neu'),
#  ('財政', 'Na'),
#  ('年度', 'Na'),
#  ('預算案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('重點', 'Na'),
#  ('包括', 'VK'),
#  ('增進', 'VC'),
#  ('美國', 'Nc'),
#  ('在', 'P'),
#  ('全球', 'Nc'),
#  ('的', 'DE'),
#  ('嚇阻力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因應', 'VJ'),
#  ('主要', 'A'),
#  ('對手', 'Na'),
#  ('中國', 'Nc'),
#  ('帶來', 'VC'),
#  ('的', 'DE'),
#  ('挑戰', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('其中', 'Nep'),
#  ('國務院', 'Nc'),
#  ('請求', 'VF'),
#  ('編列', 'VC'),
#  ('1億', 'Neu'),
#  ('美元', 'Nf'),
#  ('協助', 'VC'),
#  ('台灣', 'Nc'),
#  ('強化', 'VHC'),
#  ('嚇阻力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('維持', 'VJ'),
#  ('台海', 'Nc'),
#  ('和平', 'VH'),
#  ('穩定', 'VHC'),
#  ('。', 'PERIODCATEGORY'),
#  ('根據', 'P'),
#  ('美國', 'Nc'),
#  ('國務院', 'Nc'),
#  ('的', 'DE'),
#  ('新聞稿', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2025', 'Neu'),
#  ('財政', 'Na'),
#  ('年度', 'Na'),
#  ('預算案', 'Na'),
#  ('將', 'D'),
#  ('提供', 'VD'),
#  ('資源', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('供', 'VF'),
#  ('國務院', 'Nc'),
#  ('和', 'Caa'),
#  ('美國', 'Nc'),
#  ('國際', 'Nc'),
#  ('開發', 'VC'),
#  ('總署', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('USAID', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('擴大', 'VC'),
#  ('與', 'P'),
#  ('國際', 'Nc'),
#  ('夥伴', 'Na'),
#  ('的', 'DE'),
#  ('合作', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('深化', 'VHC'),
#  ('關係', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('在', 'P'),
#  ('台灣', 'Nc'),
#  ('方面', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('國務院', 'Nc'),
#  ('請求', 'VF'),
#  ('編列', 'VC'),
#  ('1億', 'Neu'),
#  ('美元', 'Nf'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('約', 'Da'),
#  ('新台幣', 'Na'),
#  ('31億4000萬元', 'Neu'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('持續', 'VL'),
#  ('投資', 'VC'),
#  ('於', 'P'),
#  ('增強', 'VHC'),
#  ('台灣', 'Nc'),
#  ('安全', 'VH'),
#  ('的', 'DE'),
#  ('計畫', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('其中', 'Nep'),
#  ('也', 'D'),
#  ('包括', 'VK'),
#  ('透過', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('外國', 'Nc'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Foreign', 'FW'),
#  (' Military', 'FW'),
#  (' Financing，', 'FW'),
#  ('FMF', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('方式', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('向', 'P'),
#  ('台灣', 'Nc'),
#  ('提供', 'VD'),
#  ('軍援', 'Na'),
#  ('的', 'DE'),
#  ('方案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('加強', 'VC'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('嚇阻', 'VC'),
#  ('能力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('維持', 'VJ'),
#  ('台灣', 'Nc'),
#  ('海峽', 'Na'),
#  ('的', 'DE'),
#  ('和平', 'VH'),
#  ('與', 'Caa'),
#  ('穩定', 'VHC'),
#  ('。', 'PERIODCATEGORY'),
#  ('美國', 'Nc'),
#  ('總統', 'Na'),
#  ('拜登', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('J', 'FW'),
#  ('oe Biden', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('去年', 'Nd'),
#  ('8月', 'Nd'),
#  ('提出', 'VC'),
#  ('將', 'D'),
#  ('提供', 'VD'),
#  ('台灣', 'Nc'),
#  ('8000萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('外國', 'Nc'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('的', 'DE'),
#  ('方案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('在', 'P'),
#  ('11月', 'Nd'),
#  ('簽署', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('美國', 'Nc'),
#  ('首度', 'D'),
#  ('透過', 'P'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('貸款', 'Na'),
#  ('提供', 'VD'),
#  ('台灣', 'Nc'),
#  ('軍援', 'Na'),
#  ('。', 'PERIODCATEGORY')]

# %%
row01 = row0+row1

# %%
row01
# Out:
# [('駐', 'P'),
#  ('匈牙利', 'Nc'),
#  ('代表', 'Na'),
#  ('劉世忠', 'Nb'),
#  ('日前', 'Nd'),
#  ('接受', 'VC'),
#  ('蒙特內哥羅', 'Nc'),
#  ('重要', 'VH'),
#  ('媒體', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Vijesti', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('專訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('報導', 'VE'),
#  ('刊出', 'VE'),
#  ('後', 'Ng'),
#  ('遭', 'P'),
#  ('中國', 'Nc'),
#  ('駐', 'VCL'),
#  ('蒙特內哥羅', 'Nc'),
#  ('大使館', 'Nc'),
#  ('抗議', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('要求', 'VF'),
#  ('撤除', 'VC'),
#  ('報導', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('對', 'P'),
#  ('此', 'Nep'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('回應', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('無法', 'D'),
#  ('移除', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('堅守', 'VJ'),
#  ('媒體', 'Na'),
#  ('獨立', 'VH'),
#  ('與', 'Caa'),
#  ('自由', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('隨', 'P'),
#  ('烏俄', 'Nc'),
#  ('戰爭', 'Na'),
#  ('陷入', 'VCL'),
#  ('僵局', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('東歐', 'Nc'),
#  ('媒體', 'Na'),
#  ('關注', 'VJ'),
#  ('當前', 'Nd'),
#  ('國際', 'Nc'),
#  ('衝突', 'Na'),
#  ('如何', 'D'),
#  ('影響', 'VC'),
#  ('台海', 'Nc'),
#  ('局勢', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('駐', 'VCL'),
#  ('匈牙利', 'Nc'),
#  ('代表', 'Na'),
#  ('劉世忠', 'Nb'),
#  ('近日', 'Nd'),
#  ('接受', 'VC'),
#  ('兼', 'VG'),
#  ('轄國', 'Nc'),
#  ('多', 'Neqa'),
#  ('家', 'Nf'),
#  ('媒體', 'Na'),
#  ('專訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('分析', 'VC'),
#  ('烏俄', 'Nc'),
#  ('戰爭', 'Na'),
#  ('對', 'P'),
#  ('台海局勢', 'Nc'),
#  ('影響', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('與', 'P'),
#  ('巴爾幹', 'Nc'),
#  ('地區', 'Nc'),
#  ('讀者', 'Na'),
#  ('分享', 'VJ'),
#  ('台灣', 'Nc'),
#  ('民主', 'Na'),
#  ('和', 'Caa'),
#  ('經貿', 'Na'),
#  ('發展', 'Na'),
#  ('經驗', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('針對', 'P'),
#  ('台', 'Nc'),
#  ('海', 'Nc'),
#  ('局勢', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('劉世忠', 'Nb'),
#  ('向', 'P'),
#  ('蒙特內哥羅', 'Nb'),
#  ('媒體', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Vijesti', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('說明', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('已', 'D'),
#  ('是', 'SHI'),
#  ('主權', 'Na'),
#  ('獨立', 'VH'),
#  ('的', 'DE'),
#  ('民主', 'Na'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('與', 'P'),
#  ('中華', 'Nc'),
#  ('人民', 'Na'),
#  ('共和', 'Na'),
#  ('國', 'Nc'),
#  ('互', 'D'),
#  ('不', 'D'),
#  ('隸屬', 'VJ'),
#  ('，', 'COMMACATEGORY'),
#  ('亦', 'D'),
#  ('無', 'VJ'),
#  ('宣布', 'VC'),
#  ('獨立', 'VH'),
#  ('之', 'DE'),
#  ('必要', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('強', 'VE'),
#  ('調', 'VC'),
#  ('俄烏', 'Nc'),
#  ('戰爭', 'Na'),
#  ('的', 'DE'),
#  ('爆發', 'VJ'),
#  ('讓', 'VL'),
#  ('台灣人', 'Na'),
#  ('對', 'P'),
#  ('威權', 'Na'),
#  ('國家', 'Na'),
#  ('更加', 'Dfa'),
#  ('警覺', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('捍衛', 'VC'),
#  ('民主生活', 'Na'),
#  ('方式', 'Na'),
#  ('的', 'DE'),
#  ('決心', 'Na'),
#  ('不容', 'D'),
#  ('挑戰', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('劉世忠', 'Nb'),
#  ('指出', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台海', 'Nc'),
#  ('局勢', 'Na'),
#  ('穩定', 'VHC'),
#  ('符合', 'VJ'),
#  ('各', 'Nes'),
#  ('方', 'Na'),
#  ('利益', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('包括', 'VK'),
#  ('美', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('日', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('澳', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('韓', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('菲', 'Nc'),
#  ('及', 'Caa'),
#  ('多', 'Neqa'),
#  ('個', 'Nf'),
#  ('歐洲', 'Nc'),
#  ('國家', 'Na'),
#  ('在', 'P'),
#  ('內', 'Ncd'),
#  ('之', 'DE'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('成員', 'Na'),
#  ('均', 'D'),
#  ('呼籲', 'VE'),
#  ('中國', 'Nc'),
#  ('勿', 'D'),
#  ('以', 'P'),
#  ('軍事', 'Na'),
#  ('手段', 'Na'),
#  ('破壞', 'VC'),
#  ('台海', 'Nc'),
#  ('現狀', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日新聞', 'Nb'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('也', 'D'),
#  ('關心', 'VK'),
#  ('北京', 'Nc'),
#  ('經由', 'P'),
#  ('投資', 'VC'),
#  ('擴大', 'VC'),
#  ('在', 'P'),
#  ('巴爾幹', 'Nb'),
#  ('半島', 'Na'),
#  ('影', 'Na'),
#  ('響力', 'Na'),
#  ('的', 'DE'),
#  ('問題', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('對此', 'P'),
#  ('劉世忠', 'Nb'),
#  ('回答', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('中國', 'Nc'),
#  ('透過', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('一帶一路', 'Ncd'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('在', 'P'),
#  ('巴爾幹', 'Nc'),
#  ('地區', 'Nc'),
#  ('插旗', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('該', 'Nes'),
#  ('計畫', 'VF'),
#  ('在', 'P'),
#  ('許多', 'Neqa'),
#  ('國家', 'Na'),
#  ('已', 'D'),
#  ('造成', 'VK'),
#  ('債務', 'Na'),
#  ('危機', 'Na'),
#  ('或', 'Caa'),
#  ('貪腐問題', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('成效', 'Na'),
#  ('不如', 'VJ'),
#  ('預期', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('反之', 'Dk'),
#  ('台灣', 'Nc'),
#  ('是', 'SHI'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('的', 'DE'),
#  ('良善', 'VH'),
#  ('力量', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('願', 'VK'),
#  ('透過', 'P'),
#  ('透明', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('公開', 'VHC'),
#  ('的', 'DE'),
#  ('方式', 'Na'),
#  ('協助', 'VC'),
#  ('巴爾幹國家', 'Nb'),
#  ('發展', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('舉例', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('在', 'P'),
#  ('蒙特內哥羅', 'Nc'),
#  ('等', 'Cab'),
#  ('巴爾幹島', 'Nc'),
#  ('國家', 'Na'),
#  ('與', 'Caa'),
#  ('歐洲', 'Nc'),
#  ('復興', 'VC'),
#  ('開發', 'VC'),
#  ('銀行', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('EBRD', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('合作', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('推動', 'VC'),
#  ('職業', 'Na'),
#  ('訓練', 'Na'),
#  ('計畫', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('造福', 'VC'),
#  ('許多', 'Neqa'),
#  ('當地', 'Nc'),
#  ('年輕', 'VH'),
#  ('學子', 'Na'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('亦', 'D'),
#  ('邀請', 'VC'),
#  ('巴爾幹', 'Nb'),
#  ('地區', 'Nc'),
#  ('產官學', 'Na'),
#  ('各', 'Na'),
#  ('界', 'Nc'),
#  ('人士', 'Na'),
#  ('赴', 'VCL'),
#  ('台', 'Nc'),
#  ('參加', 'VC'),
#  ('世界', 'Nc'),
#  ('智慧', 'Na'),
#  ('城市', 'Na'),
#  ('論壇', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('分享', 'VJ'),
#  ('台灣', 'Nc'),
#  ('成功', 'VH'),
#  ('經驗', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('專訪', 'VC'),
#  ('於', 'P'),
#  ('3月', 'Nd'),
#  ('10刊載', 'Nd'),
#  ('於', 'P'),
#  ('紙本', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('隔日', 'D'),
#  ('即', 'D'),
#  ('遭', 'P'),
#  ('中國', 'Nc'),
#  ('駐', 'VCL'),
#  ('蒙特內哥羅', 'Nc'),
#  ('大使館', 'Nc'),
#  ('抗議', 'VE'),
#  ('。', 'PERIODCATEGORY'),
#  ('面對', 'VC'),
#  ('撤除', 'VC'),
#  ('報導', 'VE'),
#  ('要求', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('僅', 'Da'),
#  ('向', 'P'),
#  ('對方', 'Nh'),
#  ('回應', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('無法', 'D'),
#  ('移除', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('專訪', 'VC'),
#  ('於', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nes'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('蒙語', 'Nb'),
#  ('與', 'Caa'),
#  ('英文', 'Na'),
#  ('入', 'Nc'),
#  ('口', 'Na'),
#  ('網站', 'Nc'),
#  ('目前', 'Nd'),
#  ('共計', 'VJ'),
#  ('有', 'V_2'),
#  ('近', 'Da'),
#  ('6萬', 'Neu'),
#  ('瀏覽', 'VC'),
#  ('人次', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('每日', 'Nb'),
#  ('新聞', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('隸屬', 'VJ'),
#  ('蒙特內哥羅', 'Nb'),
#  ('最', 'Dfa'),
#  ('大', 'VH'),
#  ('媒體', 'Na'),
#  ('集團', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('為', 'P'),
#  ('中間', 'Ncd'),
#  ('偏左', 'VJ'),
#  ('及', 'Caa'),
#  ('親', 'Na'),
#  ('歐派', 'Nc'),
#  ('媒體', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2018年', 'Neu'),
#  ('該', 'Nes'),
#  ('報', 'Na'),
#  ('調查', 'VE'),
#  ('記者', 'Na'),
#  ('拉基奇', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Olivera', 'FW'),
#  (' Lakić', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('因', 'Cbb'),
#  ('長期', 'Na'),
#  ('追蹤', 'VC'),
#  ('當地', 'Nc'),
#  ('政商', 'Na'),
#  ('勾結', 'VC'),
#  ('與', 'Caa'),
#  ('腐敗', 'VH'),
#  ('的', 'DE'),
#  ('新聞', 'Na'),
#  ('遭', 'P'),
#  ('槍擊', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('引起', 'VC'),
#  ('國際', 'Nc'),
#  ('社會', 'Na'),
#  ('關注', 'VJ'),
#  ('。', 'PERIODCATEGORY'),
#  ('隨著', 'P'),
#  ('去年', 'Nd'),
#  ('親', 'Nb'),
#  ('歐派', 'Nb'),
#  ('總統', 'Na'),
#  ('米', 'Nb'),
#  ('拉托維奇', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Jakov Milatović', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('上任', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('蒙', 'Nb'),
#  ('特內哥羅正', 'Nc'),
#  ('加速', 'D'),
#  ('推動', 'VC'),
#  ('入歐', 'VCL'),
#  ('，', 'COMMACATEGORY'),
#  ('在', 'P'),
#  ('成為', 'VG'),
#  ('歐盟', 'Nb'),
#  ('成員國', 'Na'),
#  ('之前', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('蒙國', 'Nc'),
#  ('必須', 'D'),
#  ('更', 'Dfa'),
#  ('強化', 'VHC'),
#  ('新聞', 'Na'),
#  ('自由', 'Na'),
#  ('與', 'Caa'),
#  ('記者', 'Na'),
#  ('安全', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('以', 'Cbb'),
#  ('符合', 'VJ'),
#  ('歐盟對', 'Nb'),
#  ('成員國', 'Na'),
#  ('媒體', 'Na'),
#  ('安全', 'VH'),
#  ('與', 'Caa'),
#  ('自由', 'VH'),
#  ('的', 'DE'),
#  ('嚴格', 'VH'),
#  ('標準', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('白宮', 'Nc'),
#  ('今天', 'Nd'),
#  ('公布', 'VE'),
#  ('2025', 'Neu'),
#  ('財政', 'Na'),
#  ('年度', 'Na'),
#  ('預算案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('重點', 'Na'),
#  ('包括', 'VK'),
#  ('增進', 'VC'),
#  ('美國', 'Nc'),
#  ('在', 'P'),
#  ('全球', 'Nc'),
#  ('的', 'DE'),
#  ('嚇阻力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因應', 'VJ'),
#  ('主要', 'A'),
#  ('對手', 'Na'),
#  ('中國', 'Nc'),
#  ('帶來', 'VC'),
#  ('的', 'DE'),
#  ('挑戰', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('其中', 'Nep'),
#  ('國務院', 'Nc'),
#  ('請求', 'VF'),
#  ('編列', 'VC'),
#  ('1億', 'Neu'),
#  ('美元', 'Nf'),
#  ('協助', 'VC'),
#  ('台灣', 'Nc'),
#  ('強化', 'VHC'),
#  ('嚇阻力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('維持', 'VJ'),
#  ('台海', 'Nc'),
#  ('和平', 'VH'),
#  ('穩定', 'VHC'),
#  ('。', 'PERIODCATEGORY'),
#  ('根據', 'P'),
#  ('美國', 'Nc'),
#  ('國務院', 'Nc'),
#  ('的', 'DE'),
#  ('新聞稿', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2025', 'Neu'),
#  ('財政', 'Na'),
#  ('年度', 'Na'),
#  ('預算案', 'Na'),
#  ('將', 'D'),
#  ('提供', 'VD'),
#  ('資源', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('供', 'VF'),
#  ('國務院', 'Nc'),
#  ('和', 'Caa'),
#  ('美國', 'Nc'),
#  ('國際', 'Nc'),
#  ('開發', 'VC'),
#  ('總署', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('USAID', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('擴大', 'VC'),
#  ('與', 'P'),
#  ('國際', 'Nc'),
#  ('夥伴', 'Na'),
#  ('的', 'DE'),
#  ('合作', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('深化', 'VHC'),
#  ('關係', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('在', 'P'),
#  ('台灣', 'Nc'),
#  ('方面', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('國務院', 'Nc'),
#  ('請求', 'VF'),
#  ('編列', 'VC'),
#  ('1億', 'Neu'),
#  ('美元', 'Nf'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('約', 'Da'),
#  ('新台幣', 'Na'),
#  ('31億4000萬元', 'Neu'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('持續', 'VL'),
#  ('投資', 'VC'),
#  ('於', 'P'),
#  ('增強', 'VHC'),
#  ('台灣', 'Nc'),
#  ('安全', 'VH'),
#  ('的', 'DE'),
#  ('計畫', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('其中', 'Nep'),
#  ('也', 'D'),
#  ('包括', 'VK'),
#  ('透過', 'P'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('外國', 'Nc'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Foreign', 'FW'),
#  (' Military', 'FW'),
#  (' Financing，', 'FW'),
#  ('FMF', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('方式', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('向', 'P'),
#  ('台灣', 'Nc'),
#  ('提供', 'VD'),
#  ('軍援', 'Na'),
#  ('的', 'DE'),
#  ('方案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('加強', 'VC'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('嚇阻', 'VC'),
#  ('能力', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('維持', 'VJ'),
#  ('台灣', 'Nc'),
#  ('海峽', 'Na'),
#  ('的', 'DE'),
#  ('和平', 'VH'),
#  ('與', 'Caa'),
#  ('穩定', 'VHC'),
#  ('。', 'PERIODCATEGORY'),
#  ('美國', 'Nc'),
#  ('總統', 'Na'),
#  ('拜登', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('J', 'FW'),
#  ('oe Biden', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('去年', 'Nd'),
#  ('8月', 'Nd'),
#  ('提出', 'VC'),
#  ('將', 'D'),
#  ('提供', 'VD'),
#  ('台灣', 'Nc'),
#  ('8000萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('外國', 'Nc'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('的', 'DE'),
#  ('方案', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('在', 'P'),
#  ('11月', 'Nd'),
#  ('簽署', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('美國', 'Nc'),
#  ('首度', 'D'),
#  ('透過', 'P'),
#  ('軍事', 'Na'),
#  ('融資', 'Na'),
#  ('貸款', 'Na'),
#  ('提供', 'VD'),
#  ('台灣', 'Nc'),
#  ('軍援', 'Na'),
#  ('。', 'PERIODCATEGORY')]

# %% [markdown]
# ## Concatenate two Counter objects

# %%
c0 =Counter( row0 )
c1 =Counter( row1 )

# %%
c0.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 36),
#  (('。', 'PERIODCATEGORY'), 10),
#  (('「', 'PARENTHESISCATEGORY'), 9),
#  (('」', 'PARENTHESISCATEGORY'), 9),
#  (('媒體', 'Na'), 8),
#  (('新聞', 'Na'), 8),
#  (('的', 'DE'), 8),
#  (('與', 'Caa'), 6),
#  (('在', 'P'), 6),
#  (('劉世忠', 'Nb'), 5)]

# %%
c1.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 14),
#  (('的', 'DE'), 9),
#  (('台灣', 'Nc'), 8),
#  (('美國', 'Nc'), 5),
#  (('。', 'PERIODCATEGORY'), 5),
#  (('國務院', 'Nc'), 4),
#  (('提供', 'VD'), 4),
#  (('（', 'PARENTHESISCATEGORY'), 4),
#  (('）', 'PARENTHESISCATEGORY'), 4),
#  (('在', 'P'), 3)]

# %%
c01 = c0+c1

# %%
c01.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 50),
#  (('的', 'DE'), 17),
#  (('。', 'PERIODCATEGORY'), 15),
#  (('台灣', 'Nc'), 13),
#  (('「', 'PARENTHESISCATEGORY'), 10),
#  (('」', 'PARENTHESISCATEGORY'), 10),
#  (('（', 'PARENTHESISCATEGORY'), 9),
#  (('）', 'PARENTHESISCATEGORY'), 9),
#  (('在', 'P'), 9),
#  (('媒體', 'Na'), 8)]

# %% [markdown]
# ## All-in-one function

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
# All-in-one function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(10)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(10)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# %%
# %%time
result = get_top_words()
# Out:
# CPU times: total: 0 ns
# Wall time: 12 ms

# %%
result[0:2]
# Out:
# [('政治',
#   [('台灣', 17),
#    ('中國', 9),
#    ('媒體', 8),
#    ('新聞', 8),
#    ('地區', 8),
#    ('蒙特內哥羅', 6),
#    ('國際', 6),
#    ('國家', 6),
#    ('人民', 6),
#    ('劉世忠', 5)]),
#  ('科技',
#   [('馬斯克', 6),
#    ('原始碼', 6),
#    ('苯胺', 6),
#    ('火箭', 5),
#    ('公司', 4),
#    ('模型', 4),
#    ('科思', 4),
#    ('日本', 3),
#    ('船舶', 3),
#    ('人員', 3)])]

# %% [markdown]
# # Save top 200 word frequency for each category

# %%
import pandas as pd

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#   category                                           top_keys
# 0       政治  [(台灣, 17), (中國, 9), (媒體, 8), (新聞, 8), (地區, 8),...
# 1       科技  [(馬斯克, 6), (原始碼, 6), (苯胺, 6), (火箭, 5), (公司, 4)...
# 2       運動  [(陳念琴, 14), (奧運, 13), (柯爾, 9), (運動, 9), (洋基, 7...
# 3       全部  [(台灣, 23), (陳念琴, 14), (奧運, 13), (媒體, 9), (新聞, ...

# %%
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)

# %% [markdown]
# # Another way (using list) to get the same result (for reference)
#
# 統計分類的熱門關鍵字

# %% [raw]
# # 過濾條件:兩個字以上 特定的詞性
# allowedPOS=['Na','Nb','Nc']
# from collections import Counter
#
# def word_frequency( token_pos_list ):
#     filtered_words =[]
#     for word, pos in token_pos_list:
#         if (pos in allowedPOS) & (len(word) >= 2):
#             filtered_words.append(word)
#         #print('%s %s' % (word, pos))
#     counter = Counter( filtered_words )
#     return counter.most_common( 200 )

# %% [raw]
# %%time
# top_words_group=[]
# group_token_pos_all=[]
# for category in news_categories:
#     df_group = df[df.category == category]
#     group_token_pos =[]
#
#     for gtp in df_group.token_pos:
#         group_token_pos += eval(gtp)
#
#     group_token_pos_all += group_token_pos
#
#     topwords = word_frequency( group_token_pos )
#     d = pd.DataFrame(topwords, columns = ['key','freq'])
#     top_words_group.append([category, topwords])

# %% [markdown]
# # Put them together

# %%
from collections import Counter
import pandas as pd

# 
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')
news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# 
# get topk keyword function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(100)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(100)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# Save top 200 word frequency for each category
top_group_words = get_top_words()
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)
